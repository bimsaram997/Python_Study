# %%
import numpy as np
import pandas as pd
a = np.array([1,2,3])
b = np.array([4,5,6])
a+b
3*a
# Out:
# array([3, 6, 9])

# %%
a*b
# Out:
# array([ 4, 10, 18])

# %%
# create 2D array
matrix =  np.array([[1,2,3], [4,5,6]])
matrix
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
newMatrix = 5*matrix
matrix + newMatrix
# Out:
# array([[ 6, 12, 18],
#        [24, 30, 36]])

# %%
# shape of array
a.shape
matrix.shape
# Out:
# (2, 3)

# %%
# pandas
df = pd.DataFrame({'a': [1,2,3], 'b':[True, False, False], 'c':['hi', 'Bimsara', None]})
df
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %%
df['a']
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %%
# statistical info of numerical colums
df.describe()
# Out:
#          a
# count  3.0
# mean   2.0
# std    1.0
# min    1.0
# 25%    1.5
# 50%    2.0
# 75%    2.5
# max    3.0

# %%
# general info about all colums
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      bool
#  2   c       2 non-null      object
# dtypes: bool(1), int64(1), object(1)
# memory usage: 183.0+ bytes

# %%
# download iris data set
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# display first 10 raws
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# line polt of single feature
iris['sepal_length'].plot()
# Out:
# <Axes: >

# %%
# line polt of all feature
iris.plot()
# Out:
# <Axes: >

# %%
# histogram of single feature
iris['sepal_length'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# histogram of all feature
iris.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)
